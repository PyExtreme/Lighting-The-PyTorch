# %% [markdown]
# **Hello Everyone**
# <br/>
#
# This is a comprehensive tutorial on Developing ensemble models in PyTorch. I will also give a detailed explanation of how to build a model using PyTorch.
# **This notebook has been divided into following sections:**
#
# * Introduction
#     1.   Limitations of Tensorflow and Keras
#     2.  Advantages of PyTorch
#
#
# * Custom Data Loading and Preprocessing
#     1. Illustrating the APIs
#     2. Data Loading and Preprocessing
#
#
# * Model Training and Evaluation
#     1. Defining the model architecture
#     2. Defining and Loss function and Optimizer
#     3. Training the model
#     4. Validating the model
#
#
# * Data Augmentation
#     1. Augmenting more data
#
#
# * Advanced Guide to Ensembling Models
#     1. Defining various models and Training them
#     2. Evaluating the models

# %%
import numpy as np
import pandas as pd
import torch.nn.functional as F
import math
from torch.optim import lr_scheduler
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn import metrics
import torch
import itertools
from torchvision import models
import torch.optim as optim
from matplotlib.ticker import MaxNLocator
import torchvision
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch import nn
from torch.utils.data import Dataset, DataLoader
import os
from torch.nn import MaxPool2d
import chainer.links as L
from PIL import Image
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")
plt.ion()

# %%
#This data is wrongly matched. Please execute this code to have the correct mapping of X and y values

data = np.load('../input/Sign-language-digits-dataset/X.npy')
target = np.load('../input/Sign-language-digits-dataset/Y.npy')
Y = np.zeros(data.shape[0])
Y[:204] = 9
Y[204:409] = 0
Y[409:615] = 7
Y[615:822] = 6
Y[822:1028] = 1
Y[1028:1236] = 8
Y[1236:1443] = 4
Y[1443:1649] = 3
Y[1649:1855] = 2
Y[1855:] = 5
X_train, X_test, y_train, y_test = train_test_split(data, Y, test_size = .02, random_state = 2) ## splitting into train and test set

# %%
#Shapes of X_train and y_train
X_train.shape, y_train.shape
# Out:
# ((2020, 64, 64), (2020,))

# %% [markdown]
# # Custom Data Loading and Processing

# %% [markdown]
# Let's understand the work of the following keywords
#
# ### torchvision
# It is used to load and prepare dataset. Using it you can create *transformations* on the input data.
# <br/>
# #### transforms
# It is used for preprocessing images and performing operations sequentially.
# <br/>
# #### num_workers
# It is used for multiprocessing.Normally, **num_workers = 4 * (number of gpus)** works well.

# %%
class DatasetProcessing(Dataset):
    
    #initialise the class variables - transform, data, target
    def __init__(self, data, target, transform=None): 
        self.transform = transform
        self.data = data.reshape((-1,64,64)).astype(np.float32)[:,:,:,None]
        # converting target to torch.LongTensor dtype
        self.target = torch.from_numpy(target).long() 
    
    #retrieve the X and y index value and return it
    def __getitem__(self, index): 
        return self.transform(self.data[index]), self.target[index]
    
    #returns the length of the data
    def __len__(self): 
        return len(list(self.data))

# %% [markdown]
# Data loading in PyTorch can be separated in 2 parts:
# <br/>
# * Data must be wrapped on a Dataset parent class where the methods __getitem__ and __len__ must be overrided. Not that,  the data is not loaded on memory by now.
# * The Dataloader reads the data and puts it into memory.
#
# Here we are working with numpy arrays which can be directly converted to torch variable for mathematical operations.Many datasets contain images which can be imported using PIL library using
# <br/>
# > *PIL.IMAGE.fromarray(img_name)*
#
# <br/>
# We use PIL instead of OpenCV because its Torch default image loader and is compatible with ToTensor() method. The PyTorch website has all the tutorials of this section using their inbuild Dataset class and it can be a toilsome task to load data in case of Custom Dataset.While loading the data, these point should be closely worked upon:
# * Setting a batch Size
# * Shuffling the data
# * Parallelizing the tasks using multiprocecssing workers.
# <br/>
#
# The **DataLoader** function  provides all of these features and you can specify them before heading to next task. The label or the target variable can be one an array or one-hot encoded depending on the loss function. For having a look at the different loss functions, please head to [Pytorch loss functions](https://pytorch.org/docs/master/nn.html#loss-functions)

# %%
# preprocessing images and performing operations sequentially
# Firstly, data is converted to PILImage, Secondly, converted to Tensor
# Thirdly, data is Normalized
transform = transforms.Compose(
    [transforms.ToPILImage(), transforms.ToTensor()])


dset_train = DatasetProcessing(X_train, y_train, transform)


train_loader = torch.utils.data.DataLoader(dset_train, batch_size=4,
                                          shuffle=True, num_workers=4)

# %%
dset_test = DatasetProcessing(X_test, y_test, transform)
test_loader = torch.utils.data.DataLoader(dset_test, batch_size=4,
                                          shuffle=True, num_workers=4)

# %% [markdown]
# Let's have a look at the Training data

# %%
plt.figure(figsize = (16, 4))
for num, x in enumerate(X_train[0:6]):
    plt.subplot(1,6,num+1)
    plt.axis('off')
    plt.imshow(x)
    plt.title(y_train[num])

# %% [markdown]
# # Training
#
# ![](https://www.researchgate.net/publication/318174473/figure/fig2/AS:614173574701099@1523441799965/The-topology-of-the-event-driven-Convnet-used-for-this-work-Where-n-is-the-size-of-the.png)
#
#
#
#
#
#
#
#
# ## Define a CNN

# %% [markdown]
# Some of the important libraries
# ### [nn](https://pytorch.org/docs/master/nn.html)
# This library contains  function for building conv nets and importing a loss function.
# Some loss functions are:
# * **binary_cross_entropy**: Function that measures the Binary Cross Entropy between the target and the output.
# * **nll_loss**: measures the The negative log likelihood loss.
# * **cross_entropy**: This criterion combines log_softmax and nll_loss in a single function.
#
# ### [optim](https://pytorch.org/docs/master/optim.html)
# torch.optim is a package implementing various optimization algorithms. To construct an Optimizer you have to give it an iterable containing the parameters (all should be Variable s) to optimize. Then, you can specify optimizer-specific options such as the learning rate, weight decay, etc.Some of the optimizers defined by this library are:
# * **Adam**: It has been proposed in [Adam: A Method for Stochastic Optimization](https://arxiv.org/abs/1412.6980)
# * **LBFGS**: Implements [L-BFGS algorithm](https://en.wikipedia.org/wiki/Limited-memory_BFGS).
# * **RMSprop**: Proposed by G. Hinton in his [course](http://www.cs.toronto.edu/~tijmen/csc321/slides/lecture_slides_lec6.pdf)
# * **SGD**: Nesterov momentum is based on the formula from [On the importance of initialization and momentum in deep learning](http://www.cs.toronto.edu/~hinton/absps/momentum.pdf)
# <br/>
#
#
# Let’s use a **Cross-Entropy loss** and **SGD with momentum**.

# %%
class Net(nn.Module):    
    
    # This constructor will initialize the model architecture
    def __init__(self):
        super(Net, self).__init__()
          
        self.cnn_layers = nn.Sequential(
            # Defining a 2D convolution layer
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1),
            # Putting a 2D Batchnorm after CNN layer
            nn.BatchNorm2d(32),
            # Adding Relu Activation
            nn.ReLU(inplace=True),
            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
          
        self.linear_layers = nn.Sequential(
            # Adding Dropout
            nn.Dropout(p = 0.5),
            nn.Linear(32 * 32 * 32, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),
            nn.Dropout(p = 0.5),
            nn.Linear(512, 10),
        )
        
    # Defining the forward pass    
    def forward(self, x):
        
        # Forward Pass through the CNN Layers 
        x = self.cnn_layers(x)
        x = x.view(x.size(0), -1)
        # Forwrd pass through Fully Connected Layers
        x = self.linear_layers(x)
        return F.log_softmax(x)

# %% [markdown]
# <!-- background: #5A0000  -->
# <!-- color: #fff -->
#
#
# # How to use optimizers?
# To construct an Optimizer you have to give it an iterable containing the parameters (all should be Variable s) to optimize. Then, you can specify optimizer-specific options such as the learning rate, weight decay, etc.<br/>
# *If you want to move the model and variables to cuda, use **model_object.cuda()** and **variable_name.cuda()***
#
# **Follow these steps to build your first model in pytorch**
#
#
# 1. Clearing the Gradients of the model parameters
# >       optimizer.zero_grad()
#
#     ** Clear out the gradients accumulated for the parameters of the network before calling loss.backward() and optimizer.step()**
#
# 2. Compute the loss
# >       criterion( predicted_target, target)
#
#     **Compute the loss between the predicted value and the target value within the loss function previously defined**
#
# 3. Backpropogation
# >       loss.backward()
#
#     **Compute the updated weights of all the model parameters**
#
# 4. Taking an optimization step
# >       optimizer.step()
#
#     ** Update the parameters of the network **

# %%
model = Net()
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()

# %%
########################################
#       Training the model             #
########################################
def train(epoch):
    model.train()
    exp_lr_scheduler.step()
    tr_loss = 0
    correct = 0
    total = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
            
        # Clearing the Gradients of the model parameters
        optimizer.zero_grad()
        output = model(data)
        pred = torch.max(output.data, 1)[1]
        correct += (pred == target).sum()
        total += len(data)
        
        # Computing the loss
        loss = criterion(output, target)
        
        # Computing the updated weights of all the model parameters
        loss.backward()
        optimizer.step()
        tr_loss = loss.item()
        if (batch_idx + 1)% 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} \t Accuracy: {} %'.format(
                epoch, (batch_idx + 1) * len(data), len(train_loader.dataset),
                100. * (batch_idx + 1) / len(train_loader), loss.item(),100 * correct / total))
            torch.save(model.state_dict(), './model.pth')
            torch.save(model.state_dict(), './optimizer.pth')
    train_loss.append(tr_loss / len(train_loader))
    train_accuracy.append(100 * correct / total)

# %% [markdown]
# ## Model Evaluation
# Now, it's time to evaluate out model. Here Evaluating means testing the model on the validation set<br/>
# *Note that I have used Functional API( F.cross_entropy( args )) so as to give an idea how it works.*

# %%
########################################
#       Evaluating the model           #
########################################

def evaluate(data_loader):
    model.eval()
    loss = 0
    correct = 0
    total = 0
    for data, target in data_loader:
        data, target = Variable(data, volatile=True), Variable(target)
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
        
        output = model(data)
        loss += F.cross_entropy(output, target, size_average=False).item()
        pred = torch.max(output.data, 1)[1]
        total += len(data)
        correct += (pred == target).sum()
    loss /= len(data_loader.dataset)
    valid_loss.append(loss)    
    valid_accuracy.append(100 * correct / total)
    print('\nAverage Validation loss: {:.5f}\tAccuracy: {} %'.format(loss, 100 * correct / total))

# %% [markdown]
# ### You can run this model for more  epochs

# %%
n_epochs = 50
train_loss = []
train_accuracy = []
valid_loss = []
valid_accuracy = []
for epoch in range(n_epochs):
    train(epoch)
    evaluate(test_loader)
# Out:
# Train Epoch: 0 [400/2020 (20%)]	Loss: 2.502653 	 Accuracy: 25 %
# Train Epoch: 0 [800/2020 (40%)]	Loss: 3.427131 	 Accuracy: 33 %
# Train Epoch: 0 [1200/2020 (59%)]	Loss: 0.920912 	 Accuracy: 37 %
# Train Epoch: 0 [1600/2020 (79%)]	Loss: 0.328895 	 Accuracy: 39 %
# Train Epoch: 0 [2000/2020 (99%)]	Loss: 0.975183 	 Accuracy: 42 %
#
# Average Validation loss: 0.86020	Accuracy: 80 %
# Train Epoch: 1 [400/2020 (20%)]	Loss: 1.042907 	 Accuracy: 53 %
# Train Epoch: 1 [800/2020 (40%)]	Loss: 1.209433 	 Accuracy: 52 %
# Train Epoch: 1 [1200/2020 (59%)]	Loss: 3.274696 	 Accuracy: 53 %
# Train Epoch: 1 [1600/2020 (79%)]	Loss: 2.068866 	 Accuracy: 54 %
# Train Epoch: 1 [2000/2020 (99%)]	Loss: 0.542592 	 Accuracy: 56 %
#
# Average Validation loss: 0.59296	Accuracy: 88 %
# Train Epoch: 2 [400/2020 (20%)]	Loss: 1.099284 	 Accuracy: 60 %
# Train Epoch: 2 [800/2020 (40%)]	Loss: 1.009785 	 Accuracy: 58 %
# Train Epoch: 2 [1200/2020 (59%)]	Loss: 0.090855 	 Accuracy: 60 %
# Train Epoch: 2 [1600/2020 (79%)]	Loss: 1.604325 	 Accuracy: 61 %
# Train Epoch: 2 [2000/2020 (99%)]	Loss: 0.942828 	 Accuracy: 61 %
#
# Average Validation loss: 1.30702	Accuracy: 61 %
# Train Epoch: 3 [400/2020 (20%)]	Loss: 2.574053 	 Accuracy: 66 %
# Train Epoch: 3 [800/2020 (40%)]	Loss: 0.705549 	 Accuracy: 65 %
# Train Epoch: 3 [1200/2020 (59%)]	Loss: 0.165466 	 Accuracy: 65 %
# Train Epoch: 3 [1600/2020 (79%)]	Loss: 0.755143 	 Accuracy: 64 %
# Train Epoch: 3 [2000/2020 (99%)]	Loss: 1.464687 	 Accuracy: 63 %
#
# Average Validation loss: 0.71142	Accuracy: 80 %
# Train Epoch: 4 [400/2020 (20%)]	Loss: 0.226079 	 Accuracy: 70 %
# Train Epoch: 4 [800/2020 (40%)]	Loss: 1.633387 	 Accuracy: 68 %
# Train Epoch: 4 [1200/2020 (59%)]	Loss: 1.429431 	 Accuracy: 66 %
# Train Epoch: 4 [1600/2020 (79%)]	Loss: 0.220297 	 Accuracy: 66 %
# Train Epoch: 4 [2000/2020 (99%)]	Loss: 0.730446 	 Accuracy: 66 %
#
# Average Validation loss: 0.49115	Accuracy: 90 %
# Train Epoch: 5 [400/2020 (20%)]	Loss: 0.923635 	 Accuracy: 65 %
# Train Epoch: 5 [800/2020 (40%)]	Loss: 0.762994 	 Accuracy: 66 %
# Train Epoch: 5 [1200/2020 (59%)]	Loss: 1.034585 	 Accuracy: 67 %
# Train Epoch: 5 [1600/2020 (79%)]	Loss: 0.718288 	 Accuracy: 66 %
# Train Epoch: 5 [2000/2020 (99%)]	Loss: 0.654880 	 Accuracy: 67 %
#
# Average Validation loss: 0.36036	Accuracy: 88 %
# Train Epoch: 6 [400/2020 (20%)]	Loss: 1.166846 	 Accuracy: 72 %
# Train Epoch: 6 [800/2020 (40%)]	Loss: 0.402962 	 Accuracy: 70 %
# Train Epoch: 6 [1200/2020 (59%)]	Loss: 0.571713 	 Accuracy: 71 %
# Train Epoch: 6 [1600/2020 (79%)]	Loss: 0.270121 	 Accuracy: 72 %
# Train Epoch: 6 [2000/2020 (99%)]	Loss: 0.717282 	 Accuracy: 73 %
#
# Average Validation loss: 0.33006	Accuracy: 88 %
# Train Epoch: 7 [400/2020 (20%)]	Loss: 1.241100 	 Accuracy: 73 %
# Train Epoch: 7 [800/2020 (40%)]	Loss: 0.618504 	 Accuracy: 73 %
# Train Epoch: 7 [1200/2020 (59%)]	Loss: 0.552628 	 Accuracy: 73 %
# Train Epoch: 7 [1600/2020 (79%)]	Loss: 0.452017 	 Accuracy: 74 %
# Train Epoch: 7 [2000/2020 (99%)]	Loss: 0.793366 	 Accuracy: 73 %
#
# Average Validation loss: 0.32233	Accuracy: 90 %
# Train Epoch: 8 [400/2020 (20%)]	Loss: 0.169141 	 Accuracy: 79 %
# Train Epoch: 8 [800/2020 (40%)]	Loss: 1.894847 	 Accuracy: 74 %
# Train Epoch: 8 [1200/2020 (59%)]	Loss: 0.178828 	 Accuracy: 75 %
# Train Epoch: 8 [1600/2020 (79%)]	Loss: 0.327297 	 Accuracy: 75 %
# Train Epoch: 8 [2000/2020 (99%)]	Loss: 1.228258 	 Accuracy: 75 %
#
# Average Validation loss: 0.25940	Accuracy: 90 %
# Train Epoch: 9 [400/2020 (20%)]	Loss: 2.917899 	 Accuracy: 78 %
# Train Epoch: 9 [800/2020 (40%)]	Loss: 0.861664 	 Accuracy: 75 %
# Train Epoch: 9 [1200/2020 (59%)]	Loss: 0.412878 	 Accuracy: 75 %
# Train Epoch: 9 [1600/2020 (79%)]	Loss: 0.328167 	 Accuracy: 75 %
# Train Epoch: 9 [2000/2020 (99%)]	Loss: 0.187831 	 Accuracy: 75 %
#
# Average Validation loss: 0.26908	Accuracy: 92 %
# Train Epoch: 10 [400/2020 (20%)]	Loss: 1.324368 	 Accuracy: 74 %
# Train Epoch: 10 [800/2020 (40%)]	Loss: 2.232842 	 Accuracy: 74 %
# Train Epoch: 10 [1200/2020 (59%)]	Loss: 0.576861 	 Accuracy: 75 %
# Train Epoch: 10 [1600/2020 (79%)]	Loss: 0.429588 	 Accuracy: 75 %
# Train Epoch: 10 [2000/2020 (99%)]	Loss: 0.604147 	 Accuracy: 75 %
#
# Average Validation loss: 0.26894	Accuracy: 95 %
# Train Epoch: 11 [400/2020 (20%)]	Loss: 0.125974 	 Accuracy: 75 %
# Train Epoch: 11 [800/2020 (40%)]	Loss: 0.129058 	 Accuracy: 76 %
# Train Epoch: 11 [1200/2020 (59%)]	Loss: 0.124557 	 Accuracy: 75 %
# Train Epoch: 11 [1600/2020 (79%)]	Loss: 0.173550 	 Accuracy: 75 %
# Train Epoch: 11 [2000/2020 (99%)]	Loss: 0.655872 	 Accuracy: 76 %
#
# Average Validation loss: 0.22806	Accuracy: 97 %
# Train Epoch: 12 [400/2020 (20%)]	Loss: 0.841385 	 Accuracy: 76 %
# Train Epoch: 12 [800/2020 (40%)]	Loss: 0.530557 	 Accuracy: 76 %
# Train Epoch: 12 [1200/2020 (59%)]	Loss: 0.100308 	 Accuracy: 75 %
# Train Epoch: 12 [1600/2020 (79%)]	Loss: 0.125879 	 Accuracy: 75 %
# Train Epoch: 12 [2000/2020 (99%)]	Loss: 0.215636 	 Accuracy: 76 %
#
# Average Validation loss: 0.24468	Accuracy: 95 %
# Train Epoch: 13 [400/2020 (20%)]	Loss: 0.984775 	 Accuracy: 80 %
# Train Epoch: 13 [800/2020 (40%)]	Loss: 0.255150 	 Accuracy: 79 %
# Train Epoch: 13 [1200/2020 (59%)]	Loss: 0.602450 	 Accuracy: 79 %
# Train Epoch: 13 [1600/2020 (79%)]	Loss: 0.123553 	 Accuracy: 79 %
# Train Epoch: 13 [2000/2020 (99%)]	Loss: 0.317757 	 Accuracy: 79 %
#
# Average Validation loss: 0.25785	Accuracy: 92 %
# Train Epoch: 14 [400/2020 (20%)]	Loss: 1.504714 	 Accuracy: 80 %
# Train Epoch: 14 [800/2020 (40%)]	Loss: 0.050657 	 Accuracy: 80 %
# Train Epoch: 14 [1200/2020 (59%)]	Loss: 0.716903 	 Accuracy: 79 %
# Train Epoch: 14 [1600/2020 (79%)]	Loss: 0.505965 	 Accuracy: 79 %
# Train Epoch: 14 [2000/2020 (99%)]	Loss: 0.421427 	 Accuracy: 79 %
#
# Average Validation loss: 0.21192	Accuracy: 95 %
# Train Epoch: 15 [400/2020 (20%)]	Loss: 0.402954 	 Accuracy: 80 %
# Train Epoch: 15 [800/2020 (40%)]	Loss: 0.344545 	 Accuracy: 79 %
# Train Epoch: 15 [1200/2020 (59%)]	Loss: 0.987208 	 Accuracy: 79 %
# Train Epoch: 15 [1600/2020 (79%)]	Loss: 0.785112 	 Accuracy: 79 %
# Train Epoch: 15 [2000/2020 (99%)]	Loss: 0.499167 	 Accuracy: 79 %
#
# Average Validation loss: 0.23898	Accuracy: 95 %
# Train Epoch: 16 [400/2020 (20%)]	Loss: 0.131908 	 Accuracy: 82 %
# Train Epoch: 16 [800/2020 (40%)]	Loss: 0.252108 	 Accuracy: 79 %
# Train Epoch: 16 [1200/2020 (59%)]	Loss: 0.296654 	 Accuracy: 78 %
# Train Epoch: 16 [1600/2020 (79%)]	Loss: 0.289424 	 Accuracy: 79 %
# Train Epoch: 16 [2000/2020 (99%)]	Loss: 0.580274 	 Accuracy: 79 %
#
# Average Validation loss: 0.24597	Accuracy: 95 %
# Train Epoch: 17 [400/2020 (20%)]	Loss: 0.154310 	 Accuracy: 78 %
# Train Epoch: 17 [800/2020 (40%)]	Loss: 0.425349 	 Accuracy: 78 %
# Train Epoch: 17 [1200/2020 (59%)]	Loss: 0.952239 	 Accuracy: 79 %
# Train Epoch: 17 [1600/2020 (79%)]	Loss: 0.131720 	 Accuracy: 77 %
# Train Epoch: 17 [2000/2020 (99%)]	Loss: 0.262654 	 Accuracy: 77 %
#
# Average Validation loss: 0.24511	Accuracy: 92 %
# Train Epoch: 18 [400/2020 (20%)]	Loss: 1.003357 	 Accuracy: 76 %
# Train Epoch: 18 [800/2020 (40%)]	Loss: 0.054598 	 Accuracy: 77 %
# Train Epoch: 18 [1200/2020 (59%)]	Loss: 0.578433 	 Accuracy: 78 %
# Train Epoch: 18 [1600/2020 (79%)]	Loss: 0.147848 	 Accuracy: 78 %
# Train Epoch: 18 [2000/2020 (99%)]	Loss: 0.128408 	 Accuracy: 78 %
#
# Average Validation loss: 0.25119	Accuracy: 92 %
# Train Epoch: 19 [400/2020 (20%)]	Loss: 0.107414 	 Accuracy: 77 %
# Train Epoch: 19 [800/2020 (40%)]	Loss: 0.174395 	 Accuracy: 80 %
# Train Epoch: 19 [1200/2020 (59%)]	Loss: 0.633157 	 Accuracy: 80 %
# Train Epoch: 19 [1600/2020 (79%)]	Loss: 0.779140 	 Accuracy: 80 %
# Train Epoch: 19 [2000/2020 (99%)]	Loss: 0.322060 	 Accuracy: 80 %
#
# Average Validation loss: 0.22948	Accuracy: 95 %
# Train Epoch: 20 [400/2020 (20%)]	Loss: 0.964512 	 Accuracy: 77 %
# Train Epoch: 20 [800/2020 (40%)]	Loss: 1.911064 	 Accuracy: 77 %
# Train Epoch: 20 [1200/2020 (59%)]	Loss: 0.179157 	 Accuracy: 78 %
# Train Epoch: 20 [1600/2020 (79%)]	Loss: 1.458525 	 Accuracy: 79 %
# Train Epoch: 20 [2000/2020 (99%)]	Loss: 0.288575 	 Accuracy: 78 %
#
# Average Validation loss: 0.23759	Accuracy: 95 %
# Train Epoch: 21 [400/2020 (20%)]	Loss: 0.257682 	 Accuracy: 78 %
# Train Epoch: 21 [800/2020 (40%)]	Loss: 1.165716 	 Accuracy: 78 %
# Train Epoch: 21 [1200/2020 (59%)]	Loss: 0.401978 	 Accuracy: 80 %
# Train Epoch: 21 [1600/2020 (79%)]	Loss: 0.529012 	 Accuracy: 79 %
# Train Epoch: 21 [2000/2020 (99%)]	Loss: 0.266381 	 Accuracy: 79 %
# Average Validation loss: 0.25716	Accuracy: 88 %
# Train Epoch: 22 [400/2020 (20%)]	Loss: 1.711074 	 Accuracy: 77 %
# Train Epoch: 22 [800/2020 (40%)]	Loss: 0.265930 	 Accuracy: 79 %
# Train Epoch: 22 [1200/2020 (59%)]	Loss: 0.599735 	 Accuracy: 79 %
# Train Epoch: 22 [1600/2020 (79%)]	Loss: 0.953181 	 Accuracy: 78 %
# Train Epoch: 22 [2000/2020 (99%)]	Loss: 0.040016 	 Accuracy: 78 %
#
# Average Validation loss: 0.24118	Accuracy: 92 %
# Train Epoch: 23 [400/2020 (20%)]	Loss: 0.028200 	 Accuracy: 78 %
# Train Epoch: 23 [800/2020 (40%)]	Loss: 1.361067 	 Accuracy: 78 %
# Train Epoch: 23 [1200/2020 (59%)]	Loss: 1.036378 	 Accuracy: 78 %
# Train Epoch: 23 [1600/2020 (79%)]	Loss: 0.124640 	 Accuracy: 78 %
# Train Epoch: 23 [2000/2020 (99%)]	Loss: 0.548963 	 Accuracy: 78 %
#
# Average Validation loss: 0.25162	Accuracy: 95 %
# Train Epoch: 24 [400/2020 (20%)]	Loss: 0.485990 	 Accuracy: 78 %
# Train Epoch: 24 [800/2020 (40%)]	Loss: 0.392342 	 Accuracy: 79 %
# Train Epoch: 24 [1200/2020 (59%)]	Loss: 0.101376 	 Accuracy: 78 %
# Train Epoch: 24 [1600/2020 (79%)]	Loss: 0.127673 	 Accuracy: 79 %
# Train Epoch: 24 [2000/2020 (99%)]	Loss: 2.862704 	 Accuracy: 79 %
#
# Average Validation loss: 0.21501	Accuracy: 95 %
# Train Epoch: 25 [400/2020 (20%)]	Loss: 0.019789 	 Accuracy: 78 %
# Train Epoch: 25 [800/2020 (40%)]	Loss: 0.419941 	 Accuracy: 78 %
# Train Epoch: 25 [1200/2020 (59%)]	Loss: 0.143921 	 Accuracy: 79 %
# Train Epoch: 25 [1600/2020 (79%)]	Loss: 0.233947 	 Accuracy: 78 %
# Train Epoch: 25 [2000/2020 (99%)]	Loss: 0.074247 	 Accuracy: 78 %
#
# Average Validation loss: 0.23354	Accuracy: 92 %
# Train Epoch: 26 [400/2020 (20%)]	Loss: 0.758470 	 Accuracy: 75 %
# Train Epoch: 26 [800/2020 (40%)]	Loss: 0.680684 	 Accuracy: 79 %
# Train Epoch: 26 [1200/2020 (59%)]	Loss: 0.141265 	 Accuracy: 78 %
# Train Epoch: 26 [1600/2020 (79%)]	Loss: 0.596788 	 Accuracy: 77 %
# Train Epoch: 26 [2000/2020 (99%)]	Loss: 1.215846 	 Accuracy: 77 %
#
# Average Validation loss: 0.22646	Accuracy: 95 %
# Train Epoch: 27 [400/2020 (20%)]	Loss: 0.637271 	 Accuracy: 79 %
# Train Epoch: 27 [800/2020 (40%)]	Loss: 0.308497 	 Accuracy: 78 %
# Train Epoch: 27 [1200/2020 (59%)]	Loss: 1.144256 	 Accuracy: 78 %
# Train Epoch: 27 [1600/2020 (79%)]	Loss: 1.374354 	 Accuracy: 78 %
# Train Epoch: 27 [2000/2020 (99%)]	Loss: 0.254584 	 Accuracy: 78 %
#
# Average Validation loss: 0.23486	Accuracy: 95 %
# Train Epoch: 28 [400/2020 (20%)]	Loss: 0.111854 	 Accuracy: 79 %
# Train Epoch: 28 [800/2020 (40%)]	Loss: 0.193981 	 Accuracy: 78 %
# Train Epoch: 28 [1200/2020 (59%)]	Loss: 0.621002 	 Accuracy: 78 %
# Train Epoch: 28 [1600/2020 (79%)]	Loss: 0.103617 	 Accuracy: 78 %
# Train Epoch: 28 [2000/2020 (99%)]	Loss: 0.329139 	 Accuracy: 78 %
#
# Average Validation loss: 0.25526	Accuracy: 95 %
# Train Epoch: 29 [400/2020 (20%)]	Loss: 0.399888 	 Accuracy: 82 %
# Train Epoch: 29 [800/2020 (40%)]	Loss: 0.828020 	 Accuracy: 80 %
# Train Epoch: 29 [1200/2020 (59%)]	Loss: 1.762275 	 Accuracy: 78 %
# Train Epoch: 29 [1600/2020 (79%)]	Loss: 0.361205 	 Accuracy: 79 %
# Train Epoch: 29 [2000/2020 (99%)]	Loss: 0.066692 	 Accuracy: 79 %
#
# Average Validation loss: 0.24549	Accuracy: 95 %
# Train Epoch: 30 [400/2020 (20%)]	Loss: 1.115716 	 Accuracy: 77 %
# Train Epoch: 30 [800/2020 (40%)]	Loss: 0.585483 	 Accuracy: 79 %
# Train Epoch: 30 [1200/2020 (59%)]	Loss: 0.124672 	 Accuracy: 78 %
# Train Epoch: 30 [1600/2020 (79%)]	Loss: 0.696163 	 Accuracy: 78 %
# Train Epoch: 30 [2000/2020 (99%)]	Loss: 0.242974 	 Accuracy: 78 %
#
# Average Validation loss: 0.23444	Accuracy: 92 %
# Train Epoch: 31 [400/2020 (20%)]	Loss: 0.289307 	 Accuracy: 80 %
# Train Epoch: 31 [800/2020 (40%)]	Loss: 0.502288 	 Accuracy: 79 %
# Train Epoch: 31 [1200/2020 (59%)]	Loss: 0.409624 	 Accuracy: 79 %
# Train Epoch: 31 [1600/2020 (79%)]	Loss: 0.137691 	 Accuracy: 79 %
# Train Epoch: 31 [2000/2020 (99%)]	Loss: 1.128938 	 Accuracy: 78 %
#
# Average Validation loss: 0.21113	Accuracy: 97 %
# Train Epoch: 32 [400/2020 (20%)]	Loss: 0.519861 	 Accuracy: 80 %
# Train Epoch: 32 [800/2020 (40%)]	Loss: 0.142657 	 Accuracy: 78 %
# Train Epoch: 32 [1200/2020 (59%)]	Loss: 0.842668 	 Accuracy: 80 %
# Train Epoch: 32 [1600/2020 (79%)]	Loss: 0.166902 	 Accuracy: 79 %
# Train Epoch: 32 [2000/2020 (99%)]	Loss: 0.595391 	 Accuracy: 78 %
#
# Average Validation loss: 0.21894	Accuracy: 95 %
# Train Epoch: 33 [400/2020 (20%)]	Loss: 1.581537 	 Accuracy: 82 %
# Train Epoch: 33 [800/2020 (40%)]	Loss: 1.151628 	 Accuracy: 80 %
# Train Epoch: 33 [1200/2020 (59%)]	Loss: 0.126561 	 Accuracy: 79 %
# Train Epoch: 33 [1600/2020 (79%)]	Loss: 0.152602 	 Accuracy: 79 %
# Train Epoch: 33 [2000/2020 (99%)]	Loss: 0.211966 	 Accuracy: 79 %
#
# Average Validation loss: 0.23670	Accuracy: 95 %
# Train Epoch: 34 [400/2020 (20%)]	Loss: 1.013232 	 Accuracy: 78 %
# Train Epoch: 34 [800/2020 (40%)]	Loss: 1.206081 	 Accuracy: 77 %
# Train Epoch: 34 [1200/2020 (59%)]	Loss: 0.508970 	 Accuracy: 77 %
# Train Epoch: 34 [1600/2020 (79%)]	Loss: 0.316205 	 Accuracy: 78 %
# Train Epoch: 34 [2000/2020 (99%)]	Loss: 0.325030 	 Accuracy: 78 %
#
# Average Validation loss: 0.23222	Accuracy: 95 %
# Train Epoch: 35 [400/2020 (20%)]	Loss: 0.585609 	 Accuracy: 77 %
# Train Epoch: 35 [800/2020 (40%)]	Loss: 1.298328 	 Accuracy: 76 %
# Train Epoch: 35 [1200/2020 (59%)]	Loss: 0.185212 	 Accuracy: 78 %
# Train Epoch: 35 [1600/2020 (79%)]	Loss: 0.683919 	 Accuracy: 78 %
# Train Epoch: 35 [2000/2020 (99%)]	Loss: 0.091779 	 Accuracy: 78 %
#
# Average Validation loss: 0.25920	Accuracy: 92 %
# Train Epoch: 36 [400/2020 (20%)]	Loss: 0.294875 	 Accuracy: 75 %
# Train Epoch: 36 [800/2020 (40%)]	Loss: 0.254370 	 Accuracy: 77 %
# Train Epoch: 36 [1200/2020 (59%)]	Loss: 0.210959 	 Accuracy: 78 %
# Train Epoch: 36 [1600/2020 (79%)]	Loss: 0.242355 	 Accuracy: 78 %
# Train Epoch: 36 [2000/2020 (99%)]	Loss: 1.142111 	 Accuracy: 79 %
#
# Average Validation loss: 0.22752	Accuracy: 92 %
# Train Epoch: 37 [400/2020 (20%)]	Loss: 0.178684 	 Accuracy: 79 %
# Train Epoch: 37 [800/2020 (40%)]	Loss: 0.277436 	 Accuracy: 77 %
# Train Epoch: 37 [1200/2020 (59%)]	Loss: 1.690337 	 Accuracy: 77 %
# Train Epoch: 37 [1600/2020 (79%)]	Loss: 0.952661 	 Accuracy: 78 %
# Train Epoch: 37 [2000/2020 (99%)]	Loss: 0.101988 	 Accuracy: 78 %
#
# Average Validation loss: 0.20881	Accuracy: 97 %
# Train Epoch: 38 [400/2020 (20%)]	Loss: 0.550544 	 Accuracy: 79 %
# Train Epoch: 38 [800/2020 (40%)]	Loss: 0.744981 	 Accuracy: 78 %
# Train Epoch: 38 [1200/2020 (59%)]	Loss: 1.440035 	 Accuracy: 78 %
# Train Epoch: 38 [1600/2020 (79%)]	Loss: 0.328180 	 Accuracy: 78 %
# Train Epoch: 38 [2000/2020 (99%)]	Loss: 0.884294 	 Accuracy: 78 %
#
# Average Validation loss: 0.23340	Accuracy: 92 %
# Train Epoch: 39 [400/2020 (20%)]	Loss: 1.500711 	 Accuracy: 81 %
# Train Epoch: 39 [800/2020 (40%)]	Loss: 0.146590 	 Accuracy: 79 %
# Train Epoch: 39 [1200/2020 (59%)]	Loss: 0.313386 	 Accuracy: 78 %
# Train Epoch: 39 [1600/2020 (79%)]	Loss: 0.552690 	 Accuracy: 78 %
# Train Epoch: 39 [2000/2020 (99%)]	Loss: 0.532613 	 Accuracy: 78 %
#
# Average Validation loss: 0.23512	Accuracy: 95 %
# Train Epoch: 40 [400/2020 (20%)]	Loss: 1.871087 	 Accuracy: 77 %
# Train Epoch: 40 [800/2020 (40%)]	Loss: 0.161123 	 Accuracy: 78 %
# Train Epoch: 40 [1200/2020 (59%)]	Loss: 0.544381 	 Accuracy: 78 %
# Train Epoch: 40 [1600/2020 (79%)]	Loss: 0.749587 	 Accuracy: 77 %
# Train Epoch: 40 [2000/2020 (99%)]	Loss: 0.148354 	 Accuracy: 78 %
#
# Average Validation loss: 0.22784	Accuracy: 95 %
# Train Epoch: 41 [400/2020 (20%)]	Loss: 0.065427 	 Accuracy: 78 %
# Train Epoch: 41 [800/2020 (40%)]	Loss: 1.031516 	 Accuracy: 78 %
# Train Epoch: 41 [1200/2020 (59%)]	Loss: 0.780955 	 Accuracy: 79 %
# Train Epoch: 41 [1600/2020 (79%)]	Loss: 1.086075 	 Accuracy: 79 %
# Train Epoch: 41 [2000/2020 (99%)]	Loss: 0.353964 	 Accuracy: 80 %
#
# Average Validation loss: 0.23675	Accuracy: 95 %
# Train Epoch: 42 [400/2020 (20%)]	Loss: 1.152927 	 Accuracy: 77 %
# Train Epoch: 42 [800/2020 (40%)]	Loss: 0.731373 	 Accuracy: 80 %
# Train Epoch: 42 [1200/2020 (59%)]	Loss: 0.255992 	 Accuracy: 80 %
# Train Epoch: 42 [1600/2020 (79%)]	Loss: 0.461523 	 Accuracy: 80 %
# Train Epoch: 42 [2000/2020 (99%)]	Loss: 1.464770 	 Accuracy: 80 %
#
# Average Validation loss: 0.21728	Accuracy: 92 %
# Train Epoch: 43 [400/2020 (20%)]	Loss: 1.394907 	 Accuracy: 78 %
# Train Epoch: 43 [800/2020 (40%)]	Loss: 0.448849 	 Accuracy: 79 %
# Train Epoch: 43 [1200/2020 (59%)]	Loss: 0.378489 	 Accuracy: 79 %
# Train Epoch: 43 [1600/2020 (79%)]	Loss: 1.641127 	 Accuracy: 78 %
# Train Epoch: 43 [2000/2020 (99%)]	Loss: 1.361746 	 Accuracy: 78 %
#
# Average Validation loss: 0.23154	Accuracy: 95 %
# Train Epoch: 44 [400/2020 (20%)]	Loss: 2.111921 	 Accuracy: 78 %
# Train Epoch: 44 [800/2020 (40%)]	Loss: 1.007025 	 Accuracy: 80 %
# Train Epoch: 44 [1200/2020 (59%)]	Loss: 0.415443 	 Accuracy: 79 %
# Train Epoch: 44 [1600/2020 (79%)]	Loss: 0.433185 	 Accuracy: 79 %
# Train Epoch: 44 [2000/2020 (99%)]	Loss: 0.571803 	 Accuracy: 78 %
#
# Average Validation loss: 0.24765	Accuracy: 95 %
# Train Epoch: 45 [400/2020 (20%)]	Loss: 2.003844 	 Accuracy: 76 %
# Train Epoch: 45 [800/2020 (40%)]	Loss: 0.108440 	 Accuracy: 76 %
# Train Epoch: 45 [1200/2020 (59%)]	Loss: 1.349954 	 Accuracy: 79 %
# Train Epoch: 45 [1600/2020 (79%)]	Loss: 0.070726 	 Accuracy: 79 %
# Train Epoch: 45 [2000/2020 (99%)]	Loss: 1.474579 	 Accuracy: 79 %
#
# Average Validation loss: 0.22307	Accuracy: 97 %
# Train Epoch: 46 [400/2020 (20%)]	Loss: 0.856845 	 Accuracy: 77 %
# Train Epoch: 46 [800/2020 (40%)]	Loss: 0.677119 	 Accuracy: 78 %
# Train Epoch: 46 [1200/2020 (59%)]	Loss: 3.175135 	 Accuracy: 79 %
# Train Epoch: 46 [1600/2020 (79%)]	Loss: 0.196762 	 Accuracy: 80 %
# Train Epoch: 46 [2000/2020 (99%)]	Loss: 0.159690 	 Accuracy: 79 %
#
# Average Validation loss: 0.22698	Accuracy: 95 %
# Train Epoch: 47 [400/2020 (20%)]	Loss: 0.121512 	 Accuracy: 79 %
# Train Epoch: 47 [800/2020 (40%)]	Loss: 1.363850 	 Accuracy: 78 %
# Train Epoch: 47 [1200/2020 (59%)]	Loss: 0.381172 	 Accuracy: 80 %
# Train Epoch: 47 [1600/2020 (79%)]	Loss: 0.136098 	 Accuracy: 79 %
# Train Epoch: 47 [2000/2020 (99%)]	Loss: 0.368526 	 Accuracy: 79 %
#
# Average Validation loss: 0.25394	Accuracy: 95 %
# Train Epoch: 48 [400/2020 (20%)]	Loss: 1.902226 	 Accuracy: 78 %
# Train Epoch: 48 [800/2020 (40%)]	Loss: 0.229780 	 Accuracy: 78 %
# Train Epoch: 48 [1200/2020 (59%)]	Loss: 1.780827 	 Accuracy: 78 %
# Train Epoch: 48 [1600/2020 (79%)]	Loss: 0.437407 	 Accuracy: 77 %
# Train Epoch: 48 [2000/2020 (99%)]	Loss: 1.155737 	 Accuracy: 78 %
#
# Average Validation loss: 0.23139	Accuracy: 97 %
# Train Epoch: 49 [400/2020 (20%)]	Loss: 0.062349 	 Accuracy: 78 %
# Train Epoch: 49 [800/2020 (40%)]	Loss: 0.101338 	 Accuracy: 80 %
# Train Epoch: 49 [1200/2020 (59%)]	Loss: 1.399234 	 Accuracy: 80 %
# Train Epoch: 49 [1600/2020 (79%)]	Loss: 0.120638 	 Accuracy: 80 %
# Train Epoch: 49 [2000/2020 (99%)]	Loss: 1.136405 	 Accuracy: 79 %
#
# Average Validation loss: 0.25637	Accuracy: 95 %

# %%
########################################
#       Plotting the Graph             #
########################################

def plot_graph(epochs):
    fig = plt.figure(figsize=(20,4))
    ax = fig.add_subplot(1, 2, 1)
    plt.title("Train - Validation Loss")
    plt.plot(list(np.arange(epochs) + 1) , train_loss, label='train')
    plt.plot(list(np.arange(epochs) + 1), valid_loss, label='validation')
    plt.xlabel('num_epochs', fontsize=12)
    plt.ylabel('loss', fontsize=12)
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    plt.legend(loc='best')
    
    ax = fig.add_subplot(1, 2, 2)
    plt.title("Train - Validation Accuracy")
    plt.plot(list(np.arange(epochs) + 1) , train_accuracy, label='train')
    plt.plot(list(np.arange(epochs) + 1), valid_accuracy, label='validation')
    plt.xlabel('num_epochs', fontsize=12)
    plt.ylabel('accuracy', fontsize=12)
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    plt.legend(loc='best')

# %%
plot_graph(n_epochs)

# %% [markdown]
# ### Let us now have a look at our model predictions.

# %%
_, (validation_data, target) = next(enumerate(test_loader))
with torch.no_grad():
    output = model(validation_data.cuda())
fig = plt.figure()
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.tight_layout()
    plt.imshow(validation_data[i][0], interpolation='none')
    pred = output.data.max(1, keepdim=True)[1][i].item()
    plt.title("Prediction: {}".format(pred))

# %% [markdown]
# ### Let us now have a look at the Predicted Probabilities of the predicted words

# %%
with torch.no_grad():
    output = model(validation_data.cuda())

softmax = torch.exp(output).cpu()
prob = list(softmax.numpy())

fig = plt.figure(figsize = (16, 8))
for i in range(0, 4):
    fig.tight_layout()
    plt.style.use('classic')
    plt.subplot(4,2, 2 * i + 1)
    plt.imshow(validation_data[i][0], interpolation='none')
    plt.xticks([])
    plt.yticks([])
    pred = output.data.max(1, keepdim=True)[1][i].item()
    plt.title("Prediction: {}".format(pred))
    plt.subplot(4,2, 2 * i + 2)
    plt.barh([0], [max(prob[i])])
    plt.yticks([])
    plt.title("Predicted Probability: {0:.2f}".format(max(prob[i])))

# %% [markdown]
# **One powerful technique to increase the  performance of any deep learning model is through adding more data. So Let's use data augmentation and see if we get some performance improvement.**

# %% [markdown]
# ## Data Augmentation

# %%
train_transform= transforms.Compose([
            transforms.ToPILImage(),
            transforms.RandomHorizontalFlip(), # Horizontal Flip
            transforms.RandomCrop(64, padding=2), # Centre Crop
            transforms.ToTensor(),  #Convereting the input to tensor
            ])
dset_train = DatasetProcessing(X_train, y_train, train_transform)
train_loader = torch.utils.data.DataLoader(dset_train, batch_size=4,
                                          shuffle=True, num_workers=4)

# %%
n_epochs = 50

train_loss = []
train_accuracy = []
valid_loss = []
valid_accuracy = []

for epoch in range(n_epochs):
    train(epoch)
    evaluate(test_loader)
# Out:
# Train Epoch: 0 [400/2020 (20%)]	Loss: 3.098755 	 Accuracy: 46 %
# Train Epoch: 0 [800/2020 (40%)]	Loss: 2.026481 	 Accuracy: 47 %
# Train Epoch: 0 [1200/2020 (59%)]	Loss: 2.328084 	 Accuracy: 47 %
# Train Epoch: 0 [1600/2020 (79%)]	Loss: 3.005734 	 Accuracy: 48 %
# Train Epoch: 0 [2000/2020 (99%)]	Loss: 2.024352 	 Accuracy: 48 %
#
# Average Validation loss: 0.25124	Accuracy: 92 %
# Train Epoch: 1 [400/2020 (20%)]	Loss: 1.684824 	 Accuracy: 49 %
# Train Epoch: 1 [800/2020 (40%)]	Loss: 0.991834 	 Accuracy: 50 %
# Train Epoch: 1 [1200/2020 (59%)]	Loss: 3.844894 	 Accuracy: 49 %
# Train Epoch: 1 [1600/2020 (79%)]	Loss: 0.883288 	 Accuracy: 48 %
# Train Epoch: 1 [2000/2020 (99%)]	Loss: 3.837183 	 Accuracy: 48 %
#
# Average Validation loss: 0.24466	Accuracy: 92 %
# Train Epoch: 2 [400/2020 (20%)]	Loss: 2.790306 	 Accuracy: 45 %
# Train Epoch: 2 [800/2020 (40%)]	Loss: 0.962351 	 Accuracy: 46 %
# Train Epoch: 2 [1200/2020 (59%)]	Loss: 0.417628 	 Accuracy: 46 %
# Train Epoch: 2 [1600/2020 (79%)]	Loss: 2.057050 	 Accuracy: 46 %
# Train Epoch: 2 [2000/2020 (99%)]	Loss: 0.074669 	 Accuracy: 47 %
#
# Average Validation loss: 0.27440	Accuracy: 90 %
# Train Epoch: 3 [400/2020 (20%)]	Loss: 2.482482 	 Accuracy: 43 %
# Train Epoch: 3 [800/2020 (40%)]	Loss: 1.559876 	 Accuracy: 44 %
# Train Epoch: 3 [1200/2020 (59%)]	Loss: 1.279653 	 Accuracy: 44 %
# Train Epoch: 3 [1600/2020 (79%)]	Loss: 2.474819 	 Accuracy: 45 %
# Train Epoch: 3 [2000/2020 (99%)]	Loss: 2.070963 	 Accuracy: 46 %
#
# Average Validation loss: 0.26615	Accuracy: 95 %
# Train Epoch: 4 [400/2020 (20%)]	Loss: 3.390878 	 Accuracy: 50 %
# Train Epoch: 4 [800/2020 (40%)]	Loss: 4.560825 	 Accuracy: 48 %
# Train Epoch: 4 [1200/2020 (59%)]	Loss: 0.767039 	 Accuracy: 47 %
# Train Epoch: 4 [1600/2020 (79%)]	Loss: 3.642066 	 Accuracy: 48 %
# Train Epoch: 4 [2000/2020 (99%)]	Loss: 0.896473 	 Accuracy: 48 %
#
# Average Validation loss: 0.26816	Accuracy: 90 %
# Train Epoch: 5 [400/2020 (20%)]	Loss: 3.129347 	 Accuracy: 51 %
# Train Epoch: 5 [800/2020 (40%)]	Loss: 1.090790 	 Accuracy: 48 %
# Train Epoch: 5 [1200/2020 (59%)]	Loss: 1.583512 	 Accuracy: 48 %
# Train Epoch: 5 [1600/2020 (79%)]	Loss: 3.896874 	 Accuracy: 47 %
# Train Epoch: 5 [2000/2020 (99%)]	Loss: 3.184701 	 Accuracy: 47 %
#
# Average Validation loss: 0.26773	Accuracy: 90 %
# Train Epoch: 6 [400/2020 (20%)]	Loss: 2.109337 	 Accuracy: 49 %
# Train Epoch: 6 [800/2020 (40%)]	Loss: 1.255277 	 Accuracy: 49 %
# Train Epoch: 6 [1200/2020 (59%)]	Loss: 2.444101 	 Accuracy: 48 %
# Train Epoch: 6 [1600/2020 (79%)]	Loss: 2.131161 	 Accuracy: 48 %
# Train Epoch: 6 [2000/2020 (99%)]	Loss: 3.772256 	 Accuracy: 48 %
#
# Average Validation loss: 0.28658	Accuracy: 92 %
# Train Epoch: 7 [400/2020 (20%)]	Loss: 2.659355 	 Accuracy: 47 %
# Train Epoch: 7 [800/2020 (40%)]	Loss: 1.264344 	 Accuracy: 47 %
# Train Epoch: 7 [1200/2020 (59%)]	Loss: 1.059930 	 Accuracy: 47 %
# Train Epoch: 7 [1600/2020 (79%)]	Loss: 1.536825 	 Accuracy: 47 %
# Train Epoch: 7 [2000/2020 (99%)]	Loss: 1.547725 	 Accuracy: 47 %
#
# Average Validation loss: 0.29071	Accuracy: 90 %
# Train Epoch: 8 [400/2020 (20%)]	Loss: 1.913574 	 Accuracy: 46 %
# Train Epoch: 8 [800/2020 (40%)]	Loss: 0.965857 	 Accuracy: 47 %
# Train Epoch: 8 [1200/2020 (59%)]	Loss: 1.048742 	 Accuracy: 47 %
# Train Epoch: 8 [1600/2020 (79%)]	Loss: 2.636517 	 Accuracy: 47 %
# Train Epoch: 8 [2000/2020 (99%)]	Loss: 2.760841 	 Accuracy: 46 %
#
# Average Validation loss: 0.25287	Accuracy: 92 %
# Train Epoch: 9 [400/2020 (20%)]	Loss: 1.207098 	 Accuracy: 45 %
# Train Epoch: 9 [800/2020 (40%)]	Loss: 2.407863 	 Accuracy: 47 %
# Train Epoch: 9 [1200/2020 (59%)]	Loss: 1.744882 	 Accuracy: 46 %
# Train Epoch: 9 [1600/2020 (79%)]	Loss: 2.330867 	 Accuracy: 46 %
# Train Epoch: 9 [2000/2020 (99%)]	Loss: 1.555214 	 Accuracy: 46 %
#
# Average Validation loss: 0.27914	Accuracy: 90 %
# Train Epoch: 10 [400/2020 (20%)]	Loss: 0.856683 	 Accuracy: 50 %
# Train Epoch: 10 [800/2020 (40%)]	Loss: 3.397614 	 Accuracy: 47 %
# Train Epoch: 10 [1200/2020 (59%)]	Loss: 2.954886 	 Accuracy: 47 %
# Train Epoch: 10 [1600/2020 (79%)]	Loss: 0.620619 	 Accuracy: 47 %
# Train Epoch: 10 [2000/2020 (99%)]	Loss: 1.067580 	 Accuracy: 46 %
#
# Average Validation loss: 0.28686	Accuracy: 90 %
# Train Epoch: 11 [400/2020 (20%)]	Loss: 0.544846 	 Accuracy: 50 %
# Train Epoch: 11 [800/2020 (40%)]	Loss: 0.996434 	 Accuracy: 49 %
# Train Epoch: 11 [1200/2020 (59%)]	Loss: 1.413405 	 Accuracy: 49 %
# Train Epoch: 11 [1600/2020 (79%)]	Loss: 1.656032 	 Accuracy: 48 %
# Train Epoch: 11 [2000/2020 (99%)]	Loss: 5.971186 	 Accuracy: 47 %
#
# Average Validation loss: 0.27236	Accuracy: 90 %
# Train Epoch: 12 [400/2020 (20%)]	Loss: 1.431284 	 Accuracy: 40 %
# Train Epoch: 12 [800/2020 (40%)]	Loss: 0.900513 	 Accuracy: 44 %
# Train Epoch: 12 [1200/2020 (59%)]	Loss: 3.018663 	 Accuracy: 45 %
# Train Epoch: 12 [1600/2020 (79%)]	Loss: 2.353856 	 Accuracy: 46 %
# Train Epoch: 12 [2000/2020 (99%)]	Loss: 1.763631 	 Accuracy: 46 %
#
# Average Validation loss: 0.25515	Accuracy: 95 %
# Train Epoch: 13 [400/2020 (20%)]	Loss: 3.215182 	 Accuracy: 45 %
# Train Epoch: 13 [800/2020 (40%)]	Loss: 1.256875 	 Accuracy: 46 %
# Train Epoch: 13 [1200/2020 (59%)]	Loss: 1.343079 	 Accuracy: 47 %
# Train Epoch: 13 [1600/2020 (79%)]	Loss: 2.376638 	 Accuracy: 47 %
# Train Epoch: 13 [2000/2020 (99%)]	Loss: 3.695175 	 Accuracy: 48 %
#
# Average Validation loss: 0.25973	Accuracy: 95 %
# Train Epoch: 14 [400/2020 (20%)]	Loss: 1.410749 	 Accuracy: 48 %
# Train Epoch: 14 [800/2020 (40%)]	Loss: 2.570903 	 Accuracy: 49 %
# Train Epoch: 14 [1200/2020 (59%)]	Loss: 1.058120 	 Accuracy: 49 %
# Train Epoch: 14 [1600/2020 (79%)]	Loss: 1.687561 	 Accuracy: 49 %
# Train Epoch: 14 [2000/2020 (99%)]	Loss: 1.908007 	 Accuracy: 50 %
#
# Average Validation loss: 0.33124	Accuracy: 85 %
# Train Epoch: 15 [400/2020 (20%)]	Loss: 1.912097 	 Accuracy: 50 %
# Train Epoch: 15 [800/2020 (40%)]	Loss: 1.183848 	 Accuracy: 50 %
# Train Epoch: 15 [1200/2020 (59%)]	Loss: 2.240032 	 Accuracy: 50 %
# Train Epoch: 15 [1600/2020 (79%)]	Loss: 1.329510 	 Accuracy: 48 %
# Train Epoch: 15 [2000/2020 (99%)]	Loss: 0.132184 	 Accuracy: 48 %
#
# Average Validation loss: 0.28711	Accuracy: 92 %
# Train Epoch: 16 [400/2020 (20%)]	Loss: 1.971078 	 Accuracy: 49 %
# Train Epoch: 16 [800/2020 (40%)]	Loss: 1.903002 	 Accuracy: 48 %
# Train Epoch: 16 [1200/2020 (59%)]	Loss: 1.476430 	 Accuracy: 49 %
# Train Epoch: 16 [1600/2020 (79%)]	Loss: 1.364595 	 Accuracy: 48 %
# Train Epoch: 16 [2000/2020 (99%)]	Loss: 3.104672 	 Accuracy: 48 %
#
# Average Validation loss: 0.26581	Accuracy: 92 %
# Train Epoch: 17 [400/2020 (20%)]	Loss: 0.132764 	 Accuracy: 51 %
# Train Epoch: 17 [800/2020 (40%)]	Loss: 1.572121 	 Accuracy: 49 %
# Train Epoch: 17 [1200/2020 (59%)]	Loss: 2.274663 	 Accuracy: 48 %
# Train Epoch: 17 [1600/2020 (79%)]	Loss: 2.996010 	 Accuracy: 49 %
# Train Epoch: 17 [2000/2020 (99%)]	Loss: 1.424023 	 Accuracy: 48 %
#
# Average Validation loss: 0.26303	Accuracy: 90 %
# Train Epoch: 18 [400/2020 (20%)]	Loss: 2.686996 	 Accuracy: 47 %
# Train Epoch: 18 [800/2020 (40%)]	Loss: 1.197484 	 Accuracy: 47 %
# Train Epoch: 18 [1200/2020 (59%)]	Loss: 0.700908 	 Accuracy: 47 %
# Train Epoch: 18 [1600/2020 (79%)]	Loss: 3.645273 	 Accuracy: 46 %
# Train Epoch: 18 [2000/2020 (99%)]	Loss: 1.134355 	 Accuracy: 47 %
#
# Average Validation loss: 0.27133	Accuracy: 92 %
# Train Epoch: 19 [400/2020 (20%)]	Loss: 0.769468 	 Accuracy: 45 %
# Train Epoch: 19 [800/2020 (40%)]	Loss: 1.101196 	 Accuracy: 48 %
# Train Epoch: 19 [1200/2020 (59%)]	Loss: 1.146206 	 Accuracy: 49 %
# Train Epoch: 19 [1600/2020 (79%)]	Loss: 1.969888 	 Accuracy: 48 %
# Train Epoch: 19 [2000/2020 (99%)]	Loss: 0.701188 	 Accuracy: 47 %
#
# Average Validation loss: 0.27188	Accuracy: 92 %
# Train Epoch: 20 [400/2020 (20%)]	Loss: 2.014294 	 Accuracy: 49 %
# Train Epoch: 20 [800/2020 (40%)]	Loss: 2.777248 	 Accuracy: 47 %
# Train Epoch: 20 [1200/2020 (59%)]	Loss: 4.177218 	 Accuracy: 47 %
# Train Epoch: 20 [1600/2020 (79%)]	Loss: 2.057329 	 Accuracy: 47 %
# Train Epoch: 20 [2000/2020 (99%)]	Loss: 3.303383 	 Accuracy: 48 %
#
# Average Validation loss: 0.28259	Accuracy: 92 %
# Train Epoch: 21 [400/2020 (20%)]	Loss: 0.781744 	 Accuracy: 46 %
# Train Epoch: 21 [800/2020 (40%)]	Loss: 4.046839 	 Accuracy: 45 %
# Train Epoch: 21 [1200/2020 (59%)]	Loss: 0.655249 	 Accuracy: 45 %
# Train Epoch: 21 [1600/2020 (79%)]	Loss: 2.600594 	 Accuracy: 45 %
# Train Epoch: 21 [2000/2020 (99%)]	Loss: 0.846664 	 Accuracy: 46 %
# Average Validation loss: 0.26971	Accuracy: 95 %
# Train Epoch: 22 [400/2020 (20%)]	Loss: 3.647740 	 Accuracy: 44 %
# Train Epoch: 22 [800/2020 (40%)]	Loss: 2.214334 	 Accuracy: 45 %
# Train Epoch: 22 [1200/2020 (59%)]	Loss: 5.317932 	 Accuracy: 45 %
# Train Epoch: 22 [1600/2020 (79%)]	Loss: 1.588667 	 Accuracy: 45 %
# Train Epoch: 22 [2000/2020 (99%)]	Loss: 1.437203 	 Accuracy: 46 %
#
# Average Validation loss: 0.28387	Accuracy: 92 %
# Train Epoch: 23 [400/2020 (20%)]	Loss: 1.004508 	 Accuracy: 48 %
# Train Epoch: 23 [800/2020 (40%)]	Loss: 1.195270 	 Accuracy: 49 %
# Train Epoch: 23 [1200/2020 (59%)]	Loss: 1.505288 	 Accuracy: 49 %
# Train Epoch: 23 [1600/2020 (79%)]	Loss: 0.300264 	 Accuracy: 48 %
# Train Epoch: 23 [2000/2020 (99%)]	Loss: 2.614928 	 Accuracy: 48 %
#
# Average Validation loss: 0.29586	Accuracy: 88 %
# Train Epoch: 24 [400/2020 (20%)]	Loss: 1.360074 	 Accuracy: 49 %
# Train Epoch: 24 [800/2020 (40%)]	Loss: 2.694679 	 Accuracy: 48 %
# Train Epoch: 24 [1200/2020 (59%)]	Loss: 4.031553 	 Accuracy: 48 %
# Train Epoch: 24 [1600/2020 (79%)]	Loss: 1.351064 	 Accuracy: 47 %
# Train Epoch: 24 [2000/2020 (99%)]	Loss: 2.315033 	 Accuracy: 46 %
#
# Average Validation loss: 0.30612	Accuracy: 92 %
# Train Epoch: 25 [400/2020 (20%)]	Loss: 1.886349 	 Accuracy: 47 %
# Train Epoch: 25 [800/2020 (40%)]	Loss: 1.236360 	 Accuracy: 45 %
# Train Epoch: 25 [1200/2020 (59%)]	Loss: 0.733594 	 Accuracy: 47 %
# Train Epoch: 25 [1600/2020 (79%)]	Loss: 3.550800 	 Accuracy: 48 %
# Train Epoch: 25 [2000/2020 (99%)]	Loss: 1.019526 	 Accuracy: 48 %
#
# Average Validation loss: 0.26770	Accuracy: 90 %
# Train Epoch: 26 [400/2020 (20%)]	Loss: 1.583161 	 Accuracy: 51 %
# Train Epoch: 26 [800/2020 (40%)]	Loss: 3.616549 	 Accuracy: 48 %
# Train Epoch: 26 [1200/2020 (59%)]	Loss: 1.788895 	 Accuracy: 49 %
# Train Epoch: 26 [1600/2020 (79%)]	Loss: 1.639616 	 Accuracy: 48 %
# Train Epoch: 26 [2000/2020 (99%)]	Loss: 4.724380 	 Accuracy: 48 %
#
# Average Validation loss: 0.26751	Accuracy: 88 %
# Train Epoch: 27 [400/2020 (20%)]	Loss: 2.414996 	 Accuracy: 47 %
# Train Epoch: 27 [800/2020 (40%)]	Loss: 1.183463 	 Accuracy: 46 %
# Train Epoch: 27 [1200/2020 (59%)]	Loss: 1.228630 	 Accuracy: 47 %
# Train Epoch: 27 [1600/2020 (79%)]	Loss: 0.197975 	 Accuracy: 47 %
# Train Epoch: 27 [2000/2020 (99%)]	Loss: 3.300272 	 Accuracy: 47 %
#
# Average Validation loss: 0.28715	Accuracy: 90 %
# Train Epoch: 28 [400/2020 (20%)]	Loss: 0.869978 	 Accuracy: 44 %
# Train Epoch: 28 [800/2020 (40%)]	Loss: 1.403214 	 Accuracy: 45 %
# Train Epoch: 28 [1200/2020 (59%)]	Loss: 3.929264 	 Accuracy: 46 %
# Train Epoch: 28 [1600/2020 (79%)]	Loss: 2.238108 	 Accuracy: 47 %
# Train Epoch: 28 [2000/2020 (99%)]	Loss: 1.178979 	 Accuracy: 47 %
#
# Average Validation loss: 0.25412	Accuracy: 92 %
# Train Epoch: 29 [400/2020 (20%)]	Loss: 0.363362 	 Accuracy: 50 %
# Train Epoch: 29 [800/2020 (40%)]	Loss: 0.533635 	 Accuracy: 48 %
# Train Epoch: 29 [1200/2020 (59%)]	Loss: 1.571827 	 Accuracy: 48 %
# Train Epoch: 29 [1600/2020 (79%)]	Loss: 5.122392 	 Accuracy: 49 %
# Train Epoch: 29 [2000/2020 (99%)]	Loss: 0.874993 	 Accuracy: 49 %
#
# Average Validation loss: 0.31039	Accuracy: 88 %
# Train Epoch: 30 [400/2020 (20%)]	Loss: 1.014919 	 Accuracy: 45 %
# Train Epoch: 30 [800/2020 (40%)]	Loss: 3.220668 	 Accuracy: 46 %
# Train Epoch: 30 [1200/2020 (59%)]	Loss: 1.963996 	 Accuracy: 46 %
# Train Epoch: 30 [1600/2020 (79%)]	Loss: 1.829161 	 Accuracy: 46 %
# Train Epoch: 30 [2000/2020 (99%)]	Loss: 2.634488 	 Accuracy: 46 %
#
# Average Validation loss: 0.28065	Accuracy: 92 %
# Train Epoch: 31 [400/2020 (20%)]	Loss: 1.892112 	 Accuracy: 49 %
# Train Epoch: 31 [800/2020 (40%)]	Loss: 0.548607 	 Accuracy: 50 %
# Train Epoch: 31 [1200/2020 (59%)]	Loss: 4.043417 	 Accuracy: 49 %
# Train Epoch: 31 [1600/2020 (79%)]	Loss: 0.550610 	 Accuracy: 49 %
# Train Epoch: 31 [2000/2020 (99%)]	Loss: 5.747791 	 Accuracy: 48 %
#
# Average Validation loss: 0.27917	Accuracy: 90 %
# Train Epoch: 32 [400/2020 (20%)]	Loss: 1.028803 	 Accuracy: 46 %
# Train Epoch: 32 [800/2020 (40%)]	Loss: 1.170181 	 Accuracy: 46 %
# Train Epoch: 32 [1200/2020 (59%)]	Loss: 1.170753 	 Accuracy: 46 %
# Train Epoch: 32 [1600/2020 (79%)]	Loss: 1.384895 	 Accuracy: 47 %
# Train Epoch: 32 [2000/2020 (99%)]	Loss: 1.575381 	 Accuracy: 47 %
#
# Average Validation loss: 0.30886	Accuracy: 88 %
# Train Epoch: 33 [400/2020 (20%)]	Loss: 2.901284 	 Accuracy: 48 %
# Train Epoch: 33 [800/2020 (40%)]	Loss: 1.061681 	 Accuracy: 47 %
# Train Epoch: 33 [1200/2020 (59%)]	Loss: 1.300492 	 Accuracy: 46 %
# Train Epoch: 33 [1600/2020 (79%)]	Loss: 2.568611 	 Accuracy: 46 %
# Train Epoch: 33 [2000/2020 (99%)]	Loss: 1.613212 	 Accuracy: 46 %
#
# Average Validation loss: 0.27992	Accuracy: 90 %
# Train Epoch: 34 [400/2020 (20%)]	Loss: 0.991338 	 Accuracy: 50 %
# Train Epoch: 34 [800/2020 (40%)]	Loss: 2.009565 	 Accuracy: 48 %
# Train Epoch: 34 [1200/2020 (59%)]	Loss: 1.012789 	 Accuracy: 49 %
# Train Epoch: 34 [1600/2020 (79%)]	Loss: 2.380396 	 Accuracy: 47 %
# Train Epoch: 34 [2000/2020 (99%)]	Loss: 1.406345 	 Accuracy: 47 %
#
# Average Validation loss: 0.27860	Accuracy: 92 %
# Train Epoch: 35 [400/2020 (20%)]	Loss: 1.500366 	 Accuracy: 47 %
# Train Epoch: 35 [800/2020 (40%)]	Loss: 3.449480 	 Accuracy: 44 %
# Train Epoch: 35 [1200/2020 (59%)]	Loss: 1.103405 	 Accuracy: 46 %
# Train Epoch: 35 [1600/2020 (79%)]	Loss: 1.430721 	 Accuracy: 45 %
# Train Epoch: 35 [2000/2020 (99%)]	Loss: 0.360764 	 Accuracy: 45 %
#
# Average Validation loss: 0.25709	Accuracy: 95 %
# Train Epoch: 36 [400/2020 (20%)]	Loss: 2.301091 	 Accuracy: 50 %
# Train Epoch: 36 [800/2020 (40%)]	Loss: 2.056719 	 Accuracy: 52 %
# Train Epoch: 36 [1200/2020 (59%)]	Loss: 1.285128 	 Accuracy: 50 %
# Train Epoch: 36 [1600/2020 (79%)]	Loss: 0.979718 	 Accuracy: 49 %
# Train Epoch: 36 [2000/2020 (99%)]	Loss: 1.803649 	 Accuracy: 49 %
#
# Average Validation loss: 0.23940	Accuracy: 95 %
# Train Epoch: 37 [400/2020 (20%)]	Loss: 3.060576 	 Accuracy: 51 %
# Train Epoch: 37 [800/2020 (40%)]	Loss: 0.238377 	 Accuracy: 49 %
# Train Epoch: 37 [1200/2020 (59%)]	Loss: 2.542981 	 Accuracy: 48 %
# Train Epoch: 37 [1600/2020 (79%)]	Loss: 4.438666 	 Accuracy: 47 %
# Train Epoch: 37 [2000/2020 (99%)]	Loss: 3.282579 	 Accuracy: 47 %
#
# Average Validation loss: 0.29157	Accuracy: 90 %
# Train Epoch: 38 [400/2020 (20%)]	Loss: 1.493029 	 Accuracy: 48 %
# Train Epoch: 38 [800/2020 (40%)]	Loss: 0.984194 	 Accuracy: 47 %
# Train Epoch: 38 [1200/2020 (59%)]	Loss: 0.980964 	 Accuracy: 48 %
# Train Epoch: 38 [1600/2020 (79%)]	Loss: 3.321755 	 Accuracy: 49 %
# Train Epoch: 38 [2000/2020 (99%)]	Loss: 0.958647 	 Accuracy: 49 %
#
# Average Validation loss: 0.27639	Accuracy: 88 %
# Train Epoch: 39 [400/2020 (20%)]	Loss: 0.918656 	 Accuracy: 48 %
# Train Epoch: 39 [800/2020 (40%)]	Loss: 1.196176 	 Accuracy: 48 %
# Train Epoch: 39 [1200/2020 (59%)]	Loss: 2.677210 	 Accuracy: 46 %
# Train Epoch: 39 [1600/2020 (79%)]	Loss: 1.897699 	 Accuracy: 45 %
# Train Epoch: 39 [2000/2020 (99%)]	Loss: 4.222878 	 Accuracy: 45 %
#
# Average Validation loss: 0.26964	Accuracy: 88 %
# Train Epoch: 40 [400/2020 (20%)]	Loss: 1.974894 	 Accuracy: 47 %
# Train Epoch: 40 [800/2020 (40%)]	Loss: 1.848032 	 Accuracy: 45 %
# Train Epoch: 40 [1200/2020 (59%)]	Loss: 1.110979 	 Accuracy: 45 %
# Train Epoch: 40 [1600/2020 (79%)]	Loss: 2.420685 	 Accuracy: 46 %
# Train Epoch: 40 [2000/2020 (99%)]	Loss: 2.174061 	 Accuracy: 46 %
#
# Average Validation loss: 0.30318	Accuracy: 90 %
# Train Epoch: 41 [400/2020 (20%)]	Loss: 2.932303 	 Accuracy: 48 %
# Train Epoch: 41 [800/2020 (40%)]	Loss: 1.913031 	 Accuracy: 48 %
# Train Epoch: 41 [1200/2020 (59%)]	Loss: 3.543480 	 Accuracy: 50 %
# Train Epoch: 41 [1600/2020 (79%)]	Loss: 1.358960 	 Accuracy: 50 %
# Train Epoch: 41 [2000/2020 (99%)]	Loss: 1.760755 	 Accuracy: 49 %
#
# Average Validation loss: 0.28242	Accuracy: 92 %
# Train Epoch: 42 [400/2020 (20%)]	Loss: 1.314233 	 Accuracy: 46 %
# Train Epoch: 42 [800/2020 (40%)]	Loss: 1.796771 	 Accuracy: 46 %
# Train Epoch: 42 [1200/2020 (59%)]	Loss: 0.933263 	 Accuracy: 49 %
# Train Epoch: 42 [1600/2020 (79%)]	Loss: 0.971489 	 Accuracy: 49 %
# Train Epoch: 42 [2000/2020 (99%)]	Loss: 3.272073 	 Accuracy: 48 %
#
# Average Validation loss: 0.23887	Accuracy: 92 %
# Train Epoch: 43 [400/2020 (20%)]	Loss: 3.258011 	 Accuracy: 45 %
# Train Epoch: 43 [800/2020 (40%)]	Loss: 1.708273 	 Accuracy: 47 %
# Train Epoch: 43 [1200/2020 (59%)]	Loss: 2.245716 	 Accuracy: 47 %
# Train Epoch: 43 [1600/2020 (79%)]	Loss: 1.638518 	 Accuracy: 48 %
# Train Epoch: 43 [2000/2020 (99%)]	Loss: 4.796373 	 Accuracy: 49 %
#
# Average Validation loss: 0.28848	Accuracy: 92 %
# Train Epoch: 44 [400/2020 (20%)]	Loss: 1.618438 	 Accuracy: 44 %
# Train Epoch: 44 [800/2020 (40%)]	Loss: 3.236441 	 Accuracy: 46 %
# Train Epoch: 44 [1200/2020 (59%)]	Loss: 0.619228 	 Accuracy: 46 %
# Train Epoch: 44 [1600/2020 (79%)]	Loss: 3.596112 	 Accuracy: 47 %
# Train Epoch: 44 [2000/2020 (99%)]	Loss: 2.229705 	 Accuracy: 47 %
#
# Average Validation loss: 0.27566	Accuracy: 90 %
# Train Epoch: 45 [400/2020 (20%)]	Loss: 3.312264 	 Accuracy: 47 %
# Train Epoch: 45 [800/2020 (40%)]	Loss: 2.209084 	 Accuracy: 47 %
# Train Epoch: 45 [1200/2020 (59%)]	Loss: 0.578252 	 Accuracy: 47 %
# Train Epoch: 45 [1600/2020 (79%)]	Loss: 2.188265 	 Accuracy: 47 %
# Train Epoch: 45 [2000/2020 (99%)]	Loss: 4.171846 	 Accuracy: 46 %
#
# Average Validation loss: 0.24412	Accuracy: 92 %
# Train Epoch: 46 [400/2020 (20%)]	Loss: 1.354724 	 Accuracy: 49 %
# Train Epoch: 46 [800/2020 (40%)]	Loss: 1.363848 	 Accuracy: 47 %
# Train Epoch: 46 [1200/2020 (59%)]	Loss: 3.282115 	 Accuracy: 45 %
# Train Epoch: 46 [1600/2020 (79%)]	Loss: 0.812637 	 Accuracy: 45 %
# Train Epoch: 46 [2000/2020 (99%)]	Loss: 4.869499 	 Accuracy: 45 %
#
# Average Validation loss: 0.28678	Accuracy: 90 %
# Train Epoch: 47 [400/2020 (20%)]	Loss: 2.039037 	 Accuracy: 49 %
# Train Epoch: 47 [800/2020 (40%)]	Loss: 3.531750 	 Accuracy: 47 %
# Train Epoch: 47 [1200/2020 (59%)]	Loss: 0.591783 	 Accuracy: 47 %
# Train Epoch: 47 [1600/2020 (79%)]	Loss: 1.793392 	 Accuracy: 48 %
# Train Epoch: 47 [2000/2020 (99%)]	Loss: 1.209201 	 Accuracy: 48 %
#
# Average Validation loss: 0.28484	Accuracy: 88 %
# Train Epoch: 48 [400/2020 (20%)]	Loss: 2.255175 	 Accuracy: 43 %
# Train Epoch: 48 [800/2020 (40%)]	Loss: 0.343106 	 Accuracy: 45 %
# Train Epoch: 48 [1200/2020 (59%)]	Loss: 3.956327 	 Accuracy: 46 %
# Train Epoch: 48 [1600/2020 (79%)]	Loss: 2.096389 	 Accuracy: 46 %
# Train Epoch: 48 [2000/2020 (99%)]	Loss: 4.094091 	 Accuracy: 46 %
#
# Average Validation loss: 0.29256	Accuracy: 90 %
# Train Epoch: 49 [400/2020 (20%)]	Loss: 3.649723 	 Accuracy: 44 %
# Train Epoch: 49 [800/2020 (40%)]	Loss: 3.312930 	 Accuracy: 46 %
# Train Epoch: 49 [1200/2020 (59%)]	Loss: 5.257158 	 Accuracy: 46 %
# Train Epoch: 49 [1600/2020 (79%)]	Loss: 2.038336 	 Accuracy: 47 %
# Train Epoch: 49 [2000/2020 (99%)]	Loss: 0.126345 	 Accuracy: 48 %
#
# Average Validation loss: 0.29616	Accuracy: 90 %

# %%
# Plotting train and validation loss
plot_graph(n_epochs)

# %% [markdown]
# # Model Predictions

# %%
_, (validation_data, target) = next(enumerate(test_loader))
with torch.no_grad():
    output = model(validation_data.cuda())
fig = plt.figure()
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.tight_layout()
    plt.imshow(validation_data[i][0], interpolation='none')
    pred = output.data.max(1, keepdim=True)[1][i].item()
    plt.title("Prediction: {}".format(pred))

# %% [markdown]
# # Model Predicted Probabilities

# %%
with torch.no_grad():
    output = model(validation_data.cuda())

softmax = torch.exp(output).cpu()
prob = list(softmax.numpy())

fig = plt.figure(figsize = (16, 8))
for i in range(0, 4):
    fig.tight_layout()
    plt.style.use('classic')
    plt.subplot(4,2, 2 * i + 1)
    plt.imshow(validation_data[i][0], interpolation='none')
    plt.xticks([])
    plt.yticks([])
    pred = output.data.max(1, keepdim=True)[1][i].item()
    plt.title("Prediction: {}".format(pred))
    plt.subplot(4,2, 2 * i + 2)
    plt.barh([0], [max(prob[i])])
    plt.yticks([])
    plt.title("Predicted Probability: {0:.2f}".format(max(prob[i])))

# %% [markdown]
# # Ensembling Models

# %% [markdown]
# **Ensemble methods is a machine learning technique that combines several base models in order to produce one optimal predictive model.  Ensemble methods usually produces more accurate solutions than a single model would. This has been the case in a number of machine learning competitions, where the winning solutions used ensemble methods. **
# ![](http://images.slideplayer.com/37/10747814/slides/slide_2.jpg)
# You can find more detailed and advanced explanation [here](https://www.springer.com/in/book/9781441993250)
# <br/>
# Finally, it's time to get hands dirty on ensemble. I have also mentioned the layer dims after each conv filter is applied.

# %%
#######################################################################
#       Defining various model architectures for ensembling           #
#######################################################################
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.pool = nn.MaxPool2d(2, 2)
    
        #1st net
        self.conv1_1 = nn.Conv2d(1, 4, kernel_size=(4, 4), padding = (3, 3), stride=(2, 2)) #34 * 34
        self.conv1_2 = nn.Conv2d(4, 8, kernel_size=(4, 4), padding = (2, 2), stride=(2, 2)) #18 * 18 #mp
        self.fc1_1 = nn.Linear(8 * 9 * 9, 32) #dropout = 0.2
        self.fc1_1_drop = nn.Dropout(p=0.2)
        self.fc1_2 = nn.Linear(32, 10)

        #2nd net
        self.conv2_1 = nn.Conv2d(1, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)) #64 * 64
        self.conv2_2 = nn.Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)) #64 * 64 #mp
        self.conv2_2_drop = nn.Dropout2d()
        self.conv2_3 = nn.Conv2d(6, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)) #64 * 64
        self.conv2_4 = nn.Conv2d(12, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)) #64 * 64 #mp
        self.conv2_4_drop = nn.Dropout2d()
        self.fc2_1 = nn.Linear(24 * 16 * 16, 120) #dropout = 0.5
        self.fc2_1_drop = nn.Dropout(p=0.5)
        self.fc2_2 = nn.Linear(120, 10)

        #3rd net
        self.conv3_1 = nn.Conv2d(1, 4, kernel_size=(5, 5), stride=(3, 3), padding=(2, 2)) #22 * 22
        self.conv3_2 = nn.Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)) #22 * 22 #mp
        self.conv3_3 = nn.Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)) #11 * 11
        self.fc3_1 = nn.Linear(16 * 11 * 11, 64) #dropout = 0.4
        self.fc3_1_drop = nn.Dropout(p=0.4)
        self.fc3_2 = nn.Linear(64, 10)

    def forward(self, x, y, z):
        x = F.relu(self.conv1_1(x))
        x = F.relu(self.pool(self.conv1_2(x)))
        x = x.view(-1, 648) #can also do x.view(-1, 1)
        x = F.relu(self.fc1_1(x))
        x = F.dropout(x, training = self.training)
        x = F.relu(self.fc1_2(x))

        y = F.relu(self.conv2_1(y))
        y = F.relu(self.pool(self.conv2_2_drop(self.conv2_2(y))))
        y = F.relu(self.conv2_3(y))
        y = F.relu(self.pool(self.conv2_4_drop(self.conv2_4(y))))
        y = y.view(-1, 256 * 24)
        y = F.relu(self.fc2_1_drop(self.fc2_1(y)))
        y = F.relu(self.fc2_2(y))

        z = F.relu(self.conv3_1(z))
        z = F.relu(self.pool(self.conv3_2(z)))
        z = F.relu(self.conv3_3(z))
        z = z.view(-1, 16 * 121)
        z = F.relu(self.fc3_1_drop(self.fc3_1(z)))
        z = F.relu(self.fc3_2(z))

        x = torch.cat((x, y, z))

        return F.sigmoid(x)

# %% [markdown]
# ![](https://saatvikshah1994.github.io/images/ensembling_1/EnsembleDepiction.png)

# %%
########################################
#       Plotting the Graph             #
########################################

def plot_graphs(train_loss, valid_loss, epochs):
    plt.style.use('ggplot')
    fig = plt.figure(figsize=(20,4))
    ax = fig.add_subplot(1, 2, 1)
    plt.title("Train Loss")
    plt.plot(list(np.arange(epochs) + 1) , train_loss, label='train')
    plt.xlabel('num_epochs', fontsize=12)
    plt.ylabel('train_loss', fontsize=12)
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    plt.legend(loc='best')
    ax = fig.add_subplot(1, 2, 2)
    plt.title("Validation Loss")
    plt.plot(list(np.arange(epochs) + 1), valid_loss, label='test')
    plt.xlabel('num_epochs', fontsize=12)
    plt.ylabel('vaidation _loss', fontsize=12)
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    plt.legend(loc='best')

# %%
##################################################
#       Training the ensembled model             #
##################################################

def train_ensemble(epoch):
    model.train()
    exp_lr_scheduler.step()
    tr_loss = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        #print(data.size())
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
        
        optimizer.zero_grad()
        target = torch.cat((target, target, target))
        output  = model(data, data, data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        tr_loss += loss.item()
        if (batch_idx + 1)% 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, (batch_idx + 1) * len(data), len(train_loader.dataset),
                100. * (batch_idx + 1) / len(train_loader), loss.item()))
    train_loss.append(tr_loss / len(train_loader))

# %%
####################################################
#       Evaluating the ensembled model             #
####################################################


def evaluate_ensemble(data_loader):
    model.eval()
    loss = 0
    
    for data, target in data_loader:
        data, target = Variable(data, volatile=True), Variable(target)
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
        
        target = torch.cat((target, target, target))
        output  = model(data, data, data)
        # Using the functional API
        loss += F.cross_entropy(output, target, size_average=False).item()
        pred = output.data.max(1, keepdim=True)[1]
        
    loss /= len(data_loader.dataset)
    valid_loss.append(loss)    
    print('\nAverage Validation loss: {:.5f}\n'.format(loss))

# %%
# Initializing the ensembled model
model = Net()
optimizer = optim.Adam(model.parameters(), lr=0.001)

criterion = nn.CrossEntropyLoss()

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()

n_epochs = 5

train_loss = []
valid_loss = []

# Training and Evaluating for n_epochs
for epoch in range(n_epochs):
    train_ensemble(epoch)
    evaluate_ensemble(test_loader)
# Out:
# Train Epoch: 0 [400/2020 (20%)]	Loss: 2.309570
# Train Epoch: 0 [800/2020 (40%)]	Loss: 2.304455
# Train Epoch: 0 [1200/2020 (59%)]	Loss: 2.293203
# Train Epoch: 0 [1600/2020 (79%)]	Loss: 2.306938
# Train Epoch: 0 [2000/2020 (99%)]	Loss: 2.302947
#
# Average Validation loss: 6.90707
#
# Train Epoch: 1 [400/2020 (20%)]	Loss: 2.303906
# Train Epoch: 1 [800/2020 (40%)]	Loss: 2.303380
# Train Epoch: 1 [1200/2020 (59%)]	Loss: 2.303722
# Train Epoch: 1 [1600/2020 (79%)]	Loss: 2.293042
# Train Epoch: 1 [2000/2020 (99%)]	Loss: 2.298905
#
# Average Validation loss: 6.90695
#
# Train Epoch: 2 [400/2020 (20%)]	Loss: 2.308300
# Train Epoch: 2 [800/2020 (40%)]	Loss: 2.273360
# Train Epoch: 2 [1200/2020 (59%)]	Loss: 2.304988
# Train Epoch: 2 [1600/2020 (79%)]	Loss: 2.283321
# Train Epoch: 2 [2000/2020 (99%)]	Loss: 2.294573
#
# Average Validation loss: 6.88311
#
# Train Epoch: 3 [400/2020 (20%)]	Loss: 2.308043
# Train Epoch: 3 [800/2020 (40%)]	Loss: 2.250308
# Train Epoch: 3 [1200/2020 (59%)]	Loss: 2.318233
# Train Epoch: 3 [1600/2020 (79%)]	Loss: 2.286651
# Train Epoch: 3 [2000/2020 (99%)]	Loss: 2.224005
#
# Average Validation loss: 6.87124
#
# Train Epoch: 4 [400/2020 (20%)]	Loss: 2.293977
# Train Epoch: 4 [800/2020 (40%)]	Loss: 2.307114
# Train Epoch: 4 [1200/2020 (59%)]	Loss: 2.269828
# Train Epoch: 4 [1600/2020 (79%)]	Loss: 2.310251
# Train Epoch: 4 [2000/2020 (99%)]	Loss: 2.309116
#
# Average Validation loss: 6.85978

# %%
plot_graphs(train_loss, valid_loss, n_epochs)
